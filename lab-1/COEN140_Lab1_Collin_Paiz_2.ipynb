# %%
import numpy as np
import time
from matplotlib import pyplot as plt

def matrices():
    mat1 = np.random.rand(100, 100)
    mat2 = np.random.rand(100, 100)
    mat3 = np.zeros([100,100])
    
    time1 = list(range(1000))
    time2 = list(range(1000))
    
    for k in range(1000):
        start = time.time()
    
        for i in range(100):
            for j in range(100):
                mat3[i][j] = mat1[i][j] + mat2[i][j]
                
        time1[k] = time.time() - start
    
    
    for k in range(1000):
        start = time.time()
        mat4 = mat1+mat2
        time2[k] = time.time() - start
    
    print("Method 1 Std Dev: ", np.std(time1))
    print("Method 1 Average: ", np.average(time1))
    
    print("Method 2 Std Dev: ", np.std(time2))
    print("Method 2 Average: ", np.average(time2))
    
    fig1 = plt.figure(figsize =(10, 7))
    
    plt.hist(time1, bins=100)
    plt.hist(time2, bins= 100)
    plt.show()
    
matrices()
# Out:
# Method 1 Std Dev:  0.00020221240292104316
# Method 1 Average:  0.00523566198348999
# Method 2 Std Dev:  2.995866545816203e-06
# Method 2 Average:  2.9845237731933595e-06

# %%
def multiplyMatrices():
    # create two nxn matrices
    mat1 = np.random.rand(3, 3)
    mat2 = np.random.rand(3, 3)
    
    # multiply the matrices using numpy matmul
    mat3 = np.matmul(mat1, mat2)
    
    #print the resulting matrix
    print(mat3)
    
multiplyMatrices()
# Out:
# [[1.66914215 1.60016137 1.32947378]
#  [1.02968455 1.02585259 0.6706784 ]
#  [0.93120239 0.90861886 0.75445626]]
